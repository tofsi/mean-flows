# %%
from plotting import plot_scalability

# %%
checkpoint_dirs = {
    "B/2": "/home/silpasoninallacheruvu/mean-flows/runs/ablations/architecture/architecture=DiT-B-2/checkpoints",
    "M/2": "/home/silpasoninallacheruvu/mean-flows/runs/ablations/architecture/architecture=DiT-M-2/checkpoints",
    "L/2": "/home/silpasoninallacheruvu/mean-flows/runs/ablations/architecture/architecture=DiT-L-2/checkpoints"
}

# %%
plot_scalability(checkpoint_dirs, output_path="/home/silpasoninallacheruvu/mean-flows/results/scalability_plot.png")
# Out:
# Plotting scalability to /home/silpasoninallacheruvu/mean-flows/results/scalability_plot.png
# Scalability Plot saved to /home/silpasoninallacheruvu/mean-flows/results/scalability_plot.png
